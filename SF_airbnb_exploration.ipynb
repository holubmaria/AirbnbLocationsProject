# %%
#import libraries and read the lisitngs dataset
import pandas as pd
import numpy as np

df = pd.read_csv("listings.csv")
df.head(20)
# Out:
#        id                                               name  host_id  \
# 0     958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1    5858                                 Creative Sanctuary     8904
# 2    7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3    8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 4    8339                    Historic Alamo Square Victorian    24215
# 5    8739                Mission Sunshine, with Private Bath     7149
# 6   10251                   Victorian Suite in Inner Mission    35199
# 7   10578                Classic Nob Hill Studio - Roof Deck    37049
# 8   10820                 Haight Buena Vista Park Garden 3BR    38836
# 9   10824         Victorian House in Hayes Valley - 3BED-2BA    38836
# 10  10832                           Union Square Modern Loft    38836
# 11  11490     Cozy Nob Hill Nook 2BR 1BA mo rental w parking    42681
# ...

# %%
df.shape
# Out:
# (6413, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6413 entries, 0 to 6412
# Data columns (total 18 columns):
# id                                6413 non-null int64
# name                              6413 non-null object
# host_id                           6413 non-null int64
# host_name                         6399 non-null object
# neighbourhood_group               0 non-null float64
# neighbourhood                     6413 non-null object
# latitude                          6413 non-null float64
# longitude                         6413 non-null float64
# room_type                         6413 non-null object
# price                             6413 non-null int64
# minimum_nights                    6413 non-null int64
# number_of_reviews                 6413 non-null int64
# last_review                       5077 non-null object
# reviews_per_month                 5077 non-null float64
# calculated_host_listings_count    6413 non-null int64
# ...

# %% [markdown]
# ### We can observe some null values for reviews_per_month and last_review but I don't need to handle these values as I will not be using them.

# %%
#how many unique neighborhoods are there?
len(df.neighbourhood.unique())
# Out:
# 36

# %%
#find unique values in the dataset
len(df.id.unique())
# Out:
# 6413

# %%
df.room_type.unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
#find duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicates

# %%
print(df.neighbourhood.unique())
# Out:
# ['Western Addition' 'Bernal Heights' 'Haight Ashbury' 'Mission' 'Nob Hill'
#  'Downtown/Civic Center' 'Castro/Upper Market' 'Noe Valley' 'Potrero Hill'
#  'Pacific Heights' 'Glen Park' 'Outer Richmond' 'Twin Peaks'
#  'Financial District' 'Outer Sunset' 'Marina' 'Inner Richmond'
#  'West of Twin Peaks' 'Bayview' 'North Beach' 'Inner Sunset'
#  'Diamond Heights' 'Chinatown' 'Russian Hill' 'South of Market' 'Parkside'
#  'Presidio Heights' 'Ocean View' 'Excelsior' 'Outer Mission' 'Lakeshore'
#  'Crocker Amazon' 'Golden Gate Park' 'Presidio' 'Seacliff'
#  'Visitacion Valley']

# %%
zero_reviews = (df['number_of_reviews_ltm']==0).sum()

# %%
print(zero_reviews)
# Out:
# 2915

# %%
#Since There are 2915 listings that don't have any reviews I am going to filter them out of the data 
# let's check the minimum nights 
zero_minnights = (df['minimum_nights']==0).sum()

# %%
print(zero_minnights)
# Out:
# 0

# %% [markdown]
# ## Exploring the reviews dataset

# %%
df_reviews = pd.read_csv("reviews.csv")

# %%
df_reviews.head()
# Out:
#    listing_id        date
# 0         958  2009-07-23
# 1         958  2009-08-03
# 2         958  2009-09-27
# 3         958  2009-11-05
# 4         958  2010-02-13

# %%
#checking the size of the dataset
df_reviews.shape
# Out:
# (285275, 2)

# %%
#checking null values
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285275 entries, 0 to 285274
# Data columns (total 2 columns):
# listing_id    285275 non-null int64
# date          285275 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# There are no null values in this dataset.

# %%
#find duplicates
df_reviews.duplicated().sum()
# Out:
# 1938

# %% [markdown]
# Checking the duplicated values

# %%
df_reviews[df_reviews.duplicated(keep='last')]
# Out:
#         listing_id        date
# 879           8739  2016-07-15
# 1580         10820  2013-02-26
# 1794         12522  2012-04-13
# 2823         23630  2013-08-23
# 4615         33578  2016-08-20
# 4871         39174  2014-09-24
# 5585         44032  2011-11-19
# 6406         53934  2015-01-04
# 6480         53934  2016-08-24
# 6490         53934  2016-10-31
# 6638         56621  2012-04-12
# 8460         70753  2014-06-16
# 8486         70753  2015-02-19
# 8550         70753  2016-06-17
# 8636         70753  2018-02-14
# 9210         72444  2016-09-12
# 9338         72444  2018-05-04
# 13575       191632  2013-09-14
# 14117       207980  2012-09-17
# 14250       207980  2016-03-31
# 14878       208831  2015-08-07
# 17577       229240  2016-07-11
# 17579       229240  2016-07-28
# 18414       241235  2016-04-07
# 18437       241235  2016-07-17
# 18502       241235  2017-07-02
# 19404       259622  2016-08-12
# 19543       269463  2013-08-13
# 19896       271647  2016-06-10
# ...

# %% [markdown]
# # Observations
# 1. After examining the duplicates, we can see that the listing ids appear more than twice but they have different dates. This is considered normal in this dataset because a listing there can be many review dates for the same listing.
# 2.  Another interesting observation is that even if both date and listing appear more than twice it may mean that there were many reviews for the same listing on the same date. Therefore I will not be removing the duplicates.
